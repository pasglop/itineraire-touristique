# %% [markdown]
# # Using Unsupervised Learning to plan Paris Vacation - clustering

# %%
import numpy as np
import pandas as pd
import seaborn as sns

try:
    import contextily as cx
except ImportError as error:
    # !pip install contextily==1.2.0;
    import contextily as cx


# !pip install haversine
import haversine as hs
import folium

try:
    import networkx as nx
except ImportError as error:
    # !pip install networkx;
    import networkx as nx
import networkx.algorithms.approximation as nx_app

sns.set_theme()
# Out:
# Requirement already satisfied: haversine in /home/david/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages (2.8.0)

# %% [markdown]
# ## Modélisation
#
# ### Choix utilisateurs

# %%
import pandas as pd
from io import StringIO

u_start_point = (48.8672391, 2.3210898) # Hotel Crillon place de la Concorde
u_nb_jour = 7
u_moyen_mobilite = "Metro" # Marche/ Velo / Voiture
u_categorie = None
u_nb_pts_max = 8 # temps min de visite 60 minutes sur 8h soit ... 8

csv_remarkable = """
id, name, latitude, longitude
678296,Tour Eiffel,48.85836,2.294543
682672,Arc de triomphe,48.873757,2.295909
4679111,Cathédrale Notre-Dame de Paris,48.85267,2.349292
705679,Centre Pompidou,48.860713,2.352254
705742,Galeries nationales du Grand Palais,48.8659,2.313395
700946,Musée du Louvre,48.861347,2.335457
680785,Observatoire panoramique de la Tour Montparnasse,48.842162,2.322114
696931,Palais Garnier,48.871663,2.331864
776370,Parc des Buttes-Chaumont,48.876913,2.381105
697984,Petit Palais - Musée des Beaux Arts de la Ville de Paris,48.865895,2.313805
697946,Philharmonie de Paris - Cité de la musique,48.889306,2.393807
"""
poi_remarkable = pd.read_csv(StringIO(csv_remarkable), sep=",", dtype=str)

# %%
poi_remarkable.head(15)
# Out:
#          id                                               name   latitude  \
# 0    678296                                        Tour Eiffel   48.85836
# 1    682672                                    Arc de triomphe  48.873757
# 2   4679111                     Cathédrale Notre-Dame de Paris   48.85267
# 3    705679                                    Centre Pompidou  48.860713
# 4    705742                Galeries nationales du Grand Palais    48.8659
# 5    700946                                    Musée du Louvre  48.861347
# 6    680785   Observatoire panoramique de la Tour Montparnasse  48.842162
# 7    696931                                     Palais Garnier  48.871663
# 8    776370                           Parc des Buttes-Chaumont  48.876913
# 9    697984  Petit Palais - Musée des Beaux Arts de la Vill...  48.865895
# 10   697946         Philharmonie de Paris - Cité de la musique  48.889306
#
#     longitude
# 0    2.294543
# 1    2.295909
# 2    2.349292
# 3    2.352254
# 4    2.313395
# 5    2.335457
# 6    2.322114
# 7    2.331864
# 8    2.381105
# 9    2.313805
# 10   2.393807

# %%
from source.databases import create_graph, connect_neo4j
from dotenv import load_dotenv
load_dotenv()


coordinates_list = []

# Iterate over the DataFrame rows and extract latitude and longitude values
for index in range(len(poi_remarkable)):
    if index >= u_nb_jour:
        break
    latitude = float(poi_remarkable.iloc[index, 2])
    longitude = float(poi_remarkable.iloc[index, 3])

    coordinates_list.append([latitude, longitude])


query = f"""
CALL gds.beta.kmeans.stream('mustseenodes', {{
  nodeProperty: 'coord',
  k: {u_nb_jour},
  seedCentroids: {coordinates_list}
}})
YIELD nodeId, communityId
RETURN gds.util.asNode(nodeId).id AS poi_id, gds.util.asNode(nodeId).name AS name, communityId as day
ORDER BY communityId, name ASC
"""
print(query)
#create_graph(query)
# Out:
# CALL gds.beta.kmeans.stream('mustseenodes', {
#   nodeProperty: 'coord',
#   k: 7,
#   seedCentroids: [[48.85836, 2.294543], [48.873757, 2.295909], [48.85267, 2.349292], [48.860713, 2.352254], [48.8659, 2.313395], [48.861347, 2.335457], [48.842162, 2.322114]]
# })
# YIELD nodeId, communityId
# RETURN gds.util.asNode(nodeId).id AS poi_id, gds.util.asNode(nodeId).name AS name, communityId as day
# ORDER BY communityId, name ASC

# %% [markdown]
# ### Constantes

# %%
#Definition des paramètres d'itinéraires
MAX_TIME_PER_DAY = 480 #8h * 60 min

MAX_KM_BY_TRANSPORT = {
    "Marche": 5, #10 km Aller / Retour
    "Velo": 10, #20 km Aller / Retour
    "Metro": 15, #30 km Aller / Retour
    "Voiture": 60 #120 km Aller / Retour
}

# Gestion de la distance max
nb_km_max = MAX_KM_BY_TRANSPORT[u_moyen_mobilite]

# Couleurs utilisées par folium pour les markers
FOLIUM_COLORS = [
    'red','blue', 'green', 'purple', 'orange', 'darkred',
    'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
    'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'
]
# Zoom a appliquer sur la carte
ZOOM_LVL = {
    'Metro': 12,
    'Velo': 15,
    'Marche': 20,
    'Voiture': 10
}

# %% [markdown]
# ## Fonctions

# %%
# Declaration des fonction
def plot_markers(dataframe, map_to_plot, color_palette = FOLIUM_COLORS, icon='star'):
    """
        Plot markers on a foilum map using coord column on a dataframe and a specified color palette
    """
    for _idx, row in dataframe.iterrows():
        color_idx = row["Jour"] - 1
        max_colors_idx = len(color_palette) - 1
        if color_idx > max_colors_idx:
            color_idx = color_idx - max_colors_idx
        color = color_palette[color_idx]
        icon_color = 'dimgray' if color == 'white' else 'white'
        folium.Marker(
            location= list(row.Coord),
            popup= f"<h5>Jour {row['Jour']}</h5><p>{row['name']}</p>",
            icon= folium.Icon(color= color, icon_color= icon_color, icon=icon)
        ).add_to(map_to_plot)

def plot_day_path(dataframe, map_to_plot, color):
    """
        Compute shortest path by creating a graph from coordonates and then plot it on a folium map in. the selected color
    """
    G = nx.Graph()
    nodes = np.arange(0, len(dataframe))
    # nodes -> array([0, 1, 2, 3, 4])
    G.add_nodes_from(nodes)

    for i in nodes:
        for j in nodes:
            if i!=j:
                G.add_edge(i, j)

    #Create a dictionary of node and coordinate of each state for positions
    positions = {node:coordinate for node, coordinate in zip(nodes, dataframe.Coord)}

    #Create a dictionary of node and capital for labels
    labels = {node:name for node, name in zip(nodes, dataframe['name'])}

    cycle = nx_app.christofides(G, weight="weight")

    folium_coordinates = []
    for lat,lon in dataframe.Coord:
        folium_coordinates.append([lat,lon])

    route = [] # u_start_point
    for stop in cycle:
        route.append(folium_coordinates[stop])
    folium.PolyLine(route, color = color, weigth = 0.5).add_to(map_to_plot)

def result_df(result):
    return pd.DataFrame(result['Jour'].value_counts().sort_index()).rename(columns= {'Jour': 'nombre POI'})

# %% [markdown]
# ### Application des paramètres utilisateurs à l'ensemble de points

# %% [markdown]
# ### Carte points par jour

# %%
import source.databases as gdb
from dotenv import load_dotenv

load_dotenv()  # take environment variables from .env.


gds = gdb.connect_gds()

gds.run_cypher("""
match (:POI)-[r:DISTANCE]->(:POI)
with collect(r) as routes, max(r.distance) as maxDistance
foreach(route in routes | set route.weight = (maxDistance + 1) - route.distance)
""")

try:
    gds.graph.drop('mustseen')
except:
    pass

G_routes, result = gds.graph.project('mustseen',
                                         "MustSeen",

                                         {"DISTANCE":
                                              {"orientation": "UNDIRECTED",
                                               "aggregation": "MAX"}
                                          }, relationshipProperties="weight")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[19], line 20
#      17 except:
#      18     pass
# ---> 20 G_routes, result = gds.graph.project('mustseen',
#      21                                          "MustSeen",
#      22
#      23                                          {"DISTANCE":
#      24                                               {"orientation": "UNDIRECTED",
#      25                                                "aggregation": "MAX"}
#      26                                           }, relationshipProperties="weight")
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/graphdatascience/graph/graph_project_runner.py:14, in GraphProjectRunner.__call__(self, graph_name, node_spec, relationship_spec, **config)
#      11 def __call__(
#      12     self, graph_name: str, node_spec: Any, relationship_spec: Any, **config: Any
#      13 ) -> Tuple[Graph, "Series[Any]"]:
# ---> 14     result = self._query_runner.run_query_with_logging(
#      15         f"CALL {self._namespace}($graph_name, $node_spec, $relationship_spec, $config)",
#      16         {
#      17             "graph_name": graph_name,
#      18             "node_spec": node_spec,
#      19             "relationship_spec": relationship_spec,
#      20             "config": config,
#      21         },
#      22     ).squeeze()
#      24     return Graph(graph_name, self._query_runner, self._server_version), result
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/graphdatascience/query_runner/neo4j_query_runner.py:107, in Neo4jQueryRunner.run_query_with_logging(self, query, params, database)
#     104 self._log(job_id, future, database)
#     106 if future.exception():
# --> 107     raise future.exception()  # type: ignore
#     108 else:
#     109     return future.result()
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/graphdatascience/query_runner/neo4j_query_runner.py:80, in Neo4jQueryRunner.run_query(self, query, params, database, custom_error)
#      73 # Though pandas support may be experimental in the `neo4j` package, it should always
#      74 # be supported in the `graphdatascience` package.
#      75 warnings.filterwarnings(
#      76     "ignore",
#      77     message=r"^pandas support is experimental and might be changed or removed in future versions$",
#      78 )
# ---> 80 return result.to_df()
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/work/result.py:724, in Result.to_df(self, expand, parse_dates)
#     721 import pandas as pd  # type: ignore[import]
#     723 if not expand:
# --> 724     df = pd.DataFrame(self.values(), columns=self._keys)
#     725 else:
#     726     df_keys = None
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/work/result.py:579, in Result.values(self, *keys)
#     561 def values(
#     562     self, *keys: _TResultKey
#     563 ) -> t.List[t.List[t.Any]]:
#     564     """Return the remainder of the result as a list of values lists.
#     565
#     566     :param keys: fields to return for each remaining record. Optionally filtering to include only certain values by index or key.
#    (...)
#     577     .. seealso:: :meth:`.Record.values`
#     578     """
# --> 579     return [record.values(*keys) for record in self]
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/work/result.py:579, in <listcomp>(.0)
#     561 def values(
#     562     self, *keys: _TResultKey
#     563 ) -> t.List[t.List[t.Any]]:
#     564     """Return the remainder of the result as a list of values lists.
#     565
#     566     :param keys: fields to return for each remaining record. Optionally filtering to include only certain values by index or key.
#    (...)
#     577     .. seealso:: :meth:`.Record.values`
#     578     """
# --> 579     return [record.values(*keys) for record in self]
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/work/result.py:251, in Result.__iter__(self)
#     249     yield self._record_buffer.popleft()
#     250 elif self._streaming:
# --> 251     self._connection.fetch_message()
#     252 elif self._discarding:
#     253     self._discard()
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:180, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     178 def inner(*args, **kwargs):
#     179     try:
# --> 180         func(*args, **kwargs)
#     181     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:808, in Bolt.fetch_message(self)
#     804 # Receive exactly one message
#     805 tag, fields = self.inbox.pop(
#     806     hydration_hooks=self.responses[0].hydration_hooks
#     807 )
# --> 808 res = self._process_message(tag, fields)
#     809 self.idle_since = perf_counter()
#     810 return res
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/io/_bolt4.py:361, in Bolt4x0._process_message(self, tag, fields)
#     359 self._server_state_manager.state = ServerStates.FAILED
#     360 try:
# --> 361     response.on_failure(summary_metadata or {})
#     362 except (ServiceUnavailable, DatabaseUnavailable):
#     363     if self.pool:
#
# File ~/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:247, in Response.on_failure(self, metadata)
#     245 handler = self.handlers.get("on_summary")
#     246 Util.callback(handler)
# --> 247 raise Neo4jError.hydrate(**metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke procedure `gds.graph.project`: Caused by: java.lang.IllegalArgumentException: A graph with name 'mustseen' already exists.}

# %%
knn = gds.beta.kmeans.stream('mustseenodes', {
    "nodeProperty": 'weight',
    "k": 7,
    "randomSeed": "42"
})

knn
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 knn = gds.beta.kmeans.stream('mustseenodes', {
#       2     "nodeProperty": 'weight',
#       3     "k": 7,
#       4     "randomSeed": "42"
#       5 })
#       7 knn
#
# TypeError: StreamModeRunner.__call__() takes 2 positional arguments but 3 were given

# %%
gds.wcc.mutate(G_routes, mutateProperty = 'componentId')

gds.graph.writeNodeProperties(G_routes, ['componentId'])
# Out:
# WARNING:root:Deprecated in favor of gds.graph.nodeProperties.write
# writeMillis                     49
# graphName                 mustseen
# nodeProperties       [componentId]
# propertiesWritten               81
# Name: 0, dtype: object

# %%
gds.run_cypher("MATCH (p:POI) RETURN p.componentId as componentId, count(*) as nodeCount ORDER BY count(*) DESC limit 1")
# Out:
#   componentId  nodeCount
# 0        None       1999

# %%
G_connected_poi, result = gds.beta.graph.project.subgraph("connected-pois", G_routes, "n.componentId = 0", "*")

# %%
X = kmean_places_to_visit[['latitude','longitude']].values
predictions = kmeans_1.fit_predict(X)
clustered = pd.concat([kmean_places_to_visit.reset_index(),
                       pd.DataFrame({'Cluster':predictions})],
                      axis=1)

clustered["Jour"] = clustered["Cluster"] + 1

kmeans_map = folium.Map(location = u_start_point , tiles = "OpenStreetMap", zoom_start = ZOOM_LVL[u_moyen_mobilite])

plot_markers(clustered, map_to_plot=kmeans_map)

kmeans_map
# Out:
# /home/david/miniconda3/envs/itineraire-touristique/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60577f6905e5db79db5b1a6b27c1d28f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60577f6905e5db79db5b1a6b27c1d28f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60577f6905e5db79db5b1a6b27c1d28f = L.map(
#                 &quot;map_60577f6905e5db79db5b1a6b27c1d28f&quot;,
#                 {
#                     center: [48.8672391, 2.3210898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f324a8b3e0e3eb7d1c8cc4f00bcd65c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_60577f6905e5db79db5b1a6b27c1d28f);
#
#
#             var marker_88a44e9b186330f3fb93d22988b73866 = L.marker(
#                 [48.904075, 2.338965],
#                 {}
#             ).addTo(map_60577f6905e5db79db5b1a6b27c1d28f);
#
#
#             var icon_09ce68bed32be7416c815f1548daf1d7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88a44e9b186330f3fb93d22988b73866.setIcon(icon_09ce68bed32be7416c815f1548daf1d7);
#
#
#         var popup_9e16a296247d96446dc43cc49dbd5f13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1eb4781e40b854141e335cbc033fa1e1 = $(`&lt;div id=&quot;html_1eb4781e40b854141e335cbc033fa1e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Jour 7&lt;/h5&gt;&lt;p&gt;Puces de Paris - Saint-Ouen&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_9e16a296247d96446dc43cc49dbd5f13.setContent(html_1eb4781e40b854141e335cbc033fa1e1);
#
#
#
#         marker_88a44e9b186330f3fb93d22988b73866.bindPopup(popup_9e16a296247d96446dc43cc49dbd5f13)
#         ;
#
#
#
#
#             var marker_bff043bda2371ef9e894a5e2f8fbe37b = L.marker(
#                 [48.843031, 2.333834],
#                 {}
#             ).addTo(map_60577f6905e5db79db5b1a6b27c1d28f);
#
#
#             var icon_17c89e29f7a5b9e32da64805b5281ad8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bff043bda2371ef9e894a5e2f8fbe37b.setIcon(icon_17c89e29f7a5b9e32da64805b5281ad8);
#
#
#         var popup_f2be826402275279c4d37b0618717809 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cdd57e51cf643292ef7e4aa63bd40a6 = $(`&lt;div id=&quot;html_3cdd57e51cf643292ef7e4aa63bd40a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Jour 6&lt;/h5&gt;&lt;p&gt;Jardin du musée Zadkine&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_f2be826402275279c4d37b0618717809.setContent(html_3cdd57e51cf643292ef7e4aa63bd40a6);
#
#
#
#         marker_bff043bda2371ef9e894a5e2f8fbe37b.bindPopup(popup_f2be826402275279c4d37b0618717809)
#         ;
#
#
#
#
#             var marker_519546f84b5092b19899421c0dd3b1c4 = L.marker(
#                 [48.871222, 2.31056],
#                 {}
#             ).addTo(map_60577f6905e5db79db5b1a6b27c1d28f);
#
#
#             var icon_0ec14e6eab75639ede03fdc08004fba5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_519546f84b5092b19899421c0dd3b1c4.setIcon(icon_0ec14e6eab75639ede03fdc08004fba5);
#
#
#         var popup_746e6dce6bd98d23a20ec806bb7d5cf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_346ebea9f40607c165041e5557b1a217 = $(`&lt;div id=&quot;html_346ebea9f40607c165041e5557b1a217&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h5&gt;Jour 7&lt;/h5&gt;&lt;p&gt;Le Boeuf sur le Toit&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_746e6dce6bd98d23a20ec806bb7d5cf9.setContent(html_346ebea9f40607c165041e5557b1a217);
#
#
#
#         marker_519546f84b5092b19899421c0dd3b1c4.bindPopup(popup_746e6dce6bd98d23a20ec806bb7d5cf9)
#         ;
#
#
#
#
#             var marker_980fafba69d8a9f8efb568fc0ed3f58f = L.marker(
#                 [48.854411, 2.335655],
#                 {}
#             ).addTo(map_60577f6905e5db79db5b1a6b27c1d28f);
